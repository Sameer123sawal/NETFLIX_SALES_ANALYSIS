# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#importing dataset
dataframe = pd.read_csv('netflix data.csv')

# %%
#check imported data
dataframe.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date month name  month_number  date    year      date.1  \
# 0    August 14, 2020     August           8.0  14.0  2020.0  14-08-2020
# 1  December 23, 2016   December          12.0  23.0  2016.0  23-12-2016
# ...

# %%
dataframe.dtypes
# Out:
# Show_Id          object
# Category         object
# Title            object
# Director         object
# Cast             object
# Country          object
# Release_Date     object
# month name       object
# month_number    float64
# date            float64
# year            float64
# date.1           object
# Rating           object
# Duration         object
# Type             object
# Description      object
# dtype: object

# %%
dataframe.rename(columns = {'date.1':'dates'}, inplace = True)

# %%
dataframe.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date month name  month_number  date    year       dates  \
# 0    August 14, 2020     August           8.0  14.0  2020.0  14-08-2020
# 1  December 23, 2016   December          12.0  23.0  2016.0  23-12-2016
# ...

# %% [markdown]
# Q.1: Is there any duplicate records in the dataset? if yes , then remove the duplicate records.

# %%
dataframe[dataframe.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date month name  month_number  date    year       dates  \
# 6300      April 5, 2019      April           4.0   5.0  2019.0  05-04-2019
# 6622  September 4, 2020  September           9.0   4.0  2020.0  04-09-2020
#
#      Rating Duration                                   Type  \
# 6300  TV-MA   97 min  Dramas, Independent Movies, Thrillers
# 6622  TV-MA   94 min   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# ...

# %%
#there are 2 duplcate records in the datasets

# %%
dataframe.drop_duplicates(inplace = True)

# %% [markdown]
# Q.2: Is there any null values in the dataset? check them and show them with hitmap

# %%
dataframe.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# month name        10
# month_number      10
# date              10
# year              10
# dates             10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
# there are null values in director, cast, country, release_date, month name, month_number,date, year, dates, rating coumns

# %%
sns.heatmap(dataframe.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Q.3:for "house of cards", what is the show id and who is the director of the show

# %%
dataframe['Title']
# Out:
# 0                                            3%
# 1                                         07:19
# 2                                         23:59
# 3                                             9
# 4                                            21
#                          ...
# 7784                                       Zozo
# 7785                                     Zubaan
# 7786                          Zulu Man in Japan
# 7787                      Zumbo's Just Desserts
# 7788    ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# Name: Title, Length: 7787, dtype: object

# %%
dataframe[dataframe['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date month name  month_number  date    year       dates  \
# 2832  November 2, 2018   November          11.0   2.0  2018.0  02-11-2018
#
#      Rating   Duration                     Type  \
# 2832  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# Q.4:In which year highest number of tv shows and movies were released ? show with bar graph

# %%
dataframe.dtypes
# Out:
# Show_Id          object
# Category         object
# Title            object
# Director         object
# Cast             object
# Country          object
# Release_Date     object
# month name       object
# month_number    float64
# date            float64
# year            float64
# dates            object
# Rating           object
# Duration         object
# Type             object
# Description      object
# dtype: object

# %%
dataframe['dates'] = pd.to_datetime(dataframe['dates'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9724\3013131873.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   dataframe['dates'] = pd.to_datetime(dataframe['dates'])

# %%
dataframe.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# month name              object
# month_number           float64
# date                   float64
# year                   float64
# dates           datetime64[ns]
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# dtype: object

# %%
dataframe['dates'].dt.year.value_counts()
# Out:
# dates
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
# number of shows and tv released by each year
dataframe['dates'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='dates'>

# %% [markdown]
# Q.5: How many movies and tv shows are in the dataset ?

# %%
dataframe.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
# there are 5377 movies and 2410 tv shows

# %% [markdown]
# Q.6: show all the movies that were released in year 2020

# %%
dataframe['years'] = dataframe['dates'].dt.year

# %%
dataframe.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date month name  month_number  date    year      dates Rating  \
# 0    August 14, 2020     August           8.0  14.0  2020.0 2020-08-14  TV-MA
# 1  December 23, 2016   December          12.0  23.0  2016.0 2016-12-23  TV-MA
# ...

# %%
dataframe[(dataframe['Category'] == 'Movie') & (dataframe['years'] == 2020)]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %% [markdown]
# Q.7: show only the tv shows that were released in india only

# %%
dataframe[(dataframe['Category']== 'TV Show') & (dataframe['Country']== 'India')]
# Out:
#      Show_Id Category                               Title     Director  \
# 86       s87  TV Show        21 Sarfarosh: Saragarhi 1897          NaN
# 132     s133  TV Show                           7 (Seven)  Nizar Shafi
# 340     s341  TV Show                        Agent Raghav          NaN
# 364     s365  TV Show                        Akbar Birbal          NaN
# 533     s534  TV Show                 Anjaan: Rural Myths          NaN
# ...      ...      ...                                 ...          ...
# 6249   s6249  TV Show                The Creative Indians          NaN
# 6400   s6399  TV Show  The Golden Years with Javed Akhtar          NaN
# 6469   s6468  TV Show              The House That Made Me          NaN
# 7294   s7293  TV Show                          Typewriter          NaN
# 7705   s7704  TV Show                     Yeh Meri Family          NaN
#
#                                                    Cast Country  \
# ...

# %% [markdown]
# Q.8: show top 10 directors who gave the highest number of tv shows & movies to netflix

# %%
dataframe['Director'].value_counts()
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
#                           ..
# Vibhu Virender Puri        1
# Lucien Jean-Baptiste       1
# Jason Krawczyk             1
# Quinn Lasher               1
# Sam Dunn                   1
# Name: count, Length: 4050, dtype: int64

# %%
dataframe['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: count, dtype: int64

# %% [markdown]
# Q.9: show all records where category is movie and type is comedy or country is uk

# %%
dataframe[(dataframe['Category']=='Movie') &(dataframe['Type']=='Comedies')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
dataframe[(dataframe['Category']=='Movie') &(dataframe['Type']=='Comedies') |(dataframe['Country'] == 'United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# Q.10:In how many movies/shows where tom cruise was cast?

# %%
data_new = dataframe.dropna()

# %%
data_new.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date month name  month_number  date    year      dates Rating  \
# 1  December 23, 2016   December          12.0  23.0  2016.0 2016-12-23  TV-MA
# 2  December 20, 2018   December          12.0  20.0  2018.0 2018-12-20      R
# ...

# %%
data_new[data_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date month name  month_number  date    year      dates  \
# 3860  January 1, 2020    January           1.0   1.0  2020.0 2020-01-01
# 5071     July 1, 2019       July           7.0   1.0  2019.0 2019-07-01
#
#      Rating Duration                        Type  \
# 3860      R  189 min  Dramas, Independent Movies
# 5071      R  134 min      Classic Movies, Dramas
#
#                                             Description   years
# 3860  Through chance, human action, past history and...  2020.0
# 5071  A fast-talking yuppie is forced to slow down w...  2019.0

# %% [markdown]
# Q.11: what are the different rating defined by netflix

# %%
dataframe['Rating'].nunique()
# Out:
# 14

# %%
dataframe['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# Q12.1:how many movies got tv-14 rating in canada?

# %%
dataframe[(dataframe['Category']=='Movie') & (dataframe['Rating']=='TV-14')]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 15       s16    Movie                    Oct-01      Kunle Afolayan
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7765   s7764    Movie                     Zenda      Avadhoot Gupte
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7770   s7769    Movie  Zindagi Kitni Haseen Hay       Anjum Shahzad
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast   Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...     India
# ...

# %%
dataframe[(dataframe['Category']=='Movie') & (dataframe['Rating']=='TV-14') & (dataframe['Country']=='Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %% [markdown]
# Q12.2: how many tv  shows got r rating after year 2018

# %%
dataframe[(dataframe['Category']=='TV Show') & (dataframe['Rating']=='R')]
# Out:
#      Show_Id Category                                Title           Director  \
# 4497   s4498  TV Show                                Nobel                NaN
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 4497  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#            Release_Date month name  month_number  date    year      dates  \
# 4497  December 10, 2016   December          12.0  10.0  2016.0 2016-12-10
# 6437     April 25, 2019      April           4.0  25.0  2019.0 2019-04-25
#
#      Rating  Duration                                             Type  \
# 4497      R  1 Season  International TV Shows, TV Dramas, TV Thrillers
# 6437      R  1 Season                                         TV Shows
#
#                                             Description   years
# ...

# %%
dataframe[(dataframe['Category']=='TV Show') & (dataframe['Rating']=='R') & (dataframe['year']> 2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date month name  month_number  date    year      dates Rating  \
# 6437  April 25, 2019      April           4.0  25.0  2019.0 2019-04-25      R
#
#       Duration      Type                                        Description  \
# 6437  1 Season  TV Shows  Trapped at a stagecoach stop as a storm rages ...
#
#        years
# 6437  2019.0

# %% [markdown]
# Q.13: what is the maximum duration of a movie on netflix?

# %%
dataframe['Duration'].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
dataframe.Duration.dtypes
# Out:
# dtype('O')

# %%
dataframe[['Minutes','Unit']] = dataframe['Duration'].str.split(' ',expand= True)

# %%
dataframe.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date month name  month_number  date    year      dates Rating  \
# 0    August 14, 2020     August           8.0  14.0  2020.0 2020-08-14  TV-MA
# 1  December 23, 2016   December          12.0  23.0  2016.0 2016-12-23  TV-MA
# ...

# %%
dataframe['Minutes'].max()
# Out:
# '99'

# %% [markdown]
# Q.14:which individual country has most number of tv shows

# %%
#creating new data frame
data_tvshow = dataframe[dataframe['Category'] == 'TV Show']

# %%
data_tvshow.head()
# Out:
#    Show_Id Category   Title              Director  \
# 0       s1  TV Show      3%                   NaN
# 5       s6  TV Show      46           Serdar Akar
# 11     s12  TV Show    1983                   NaN
# 12     s13  TV Show    1994  Diego Enrique Osorno
# 16     s17  TV Show  Feb-09                   NaN
#
#                                                  Cast                Country  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...                 Brazil
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...                 Turkey
# 11  Robert Więckiewicz, Maciej Musiał, Michalina O...  Poland, United States
# 12                                                NaN                 Mexico
# 16  Shahd El Yaseen, Shaila Sabt, Hala, Hanadi Al-...                    NaN
#
#          Release_Date month name  month_number  date    year      dates  \
# 0     August 14, 2020     August           8.0  14.0  2020.0 2020-08-14
# ...

# %%
data_tvshow.Country.value_counts()
# Out:
# Country
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: count, Length: 183, dtype: int64

# %%
data_tvshow.Country.value_counts().head(1)
# Out:
# Country
# United States    705
# Name: count, dtype: int64

# %%
# united states has most tv shows i.e, 705

# %% [markdown]
# Q.15:sort the dataset by year

# %%
dataframe.sort_values(by='year',ascending = False)
# Out:
#      Show_Id Category                         Title                 Director  \
# 5564   s5564    Movie               Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie                     Surf's Up  Ash Brannon, Chris Buck
# 980     s981  TV Show                  Bling Empire                      NaN
# 5955   s5955    Movie              Taare Zameen Par               Aamir Khan
# 366     s367    Movie                     Al acecho      Francisco D'Eufemia
# ...      ...      ...                           ...                      ...
# 3374   s3375  TV Show                      Kikoriki                      NaN
# 3492   s3493  TV Show           La Familia P. Luche                      NaN
# 3946   s3947  TV Show                         Maron                      NaN
# 5138   s5138  TV Show                  Red vs. Blue                      NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                      NaN
#
# ...

# %% [markdown]
# Q16.: find all intances where
#  1 Category is movie and type is dramas
#  2 category is tv shows and type is kids tv

# %%
dataframe.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date month name  month_number  date    year      dates Rating  \
# 0    August 14, 2020     August           8.0  14.0  2020.0 2020-08-14  TV-MA
# 1  December 23, 2016   December          12.0  23.0  2016.0 2016-12-23  TV-MA
#
#     Duration                                               Type  \
# 0  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     93 min                       Dramas, International Movies
#
#                                          Description   years Minutes     Unit
# 0  In a future where the elite inhabit an island ...  2020.0       4  Seasons
# ...

# %%
dataframe[(dataframe['Category'] == 'Movie') &(dataframe['Type']=='Dramas')|
           (dataframe['Category'] == 'TV Shows') &(dataframe['Type']=="Kids' TV") ]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...
