# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#importing dataset
dataframe = pd.read_csv('netflix data.csv')

# %% [markdown]
# ### geting some basics information about the data

# %% [markdown]
# # head()

# %%
#check imported data
dataframe.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date month name  month_number  date    year      date.1  \
# 0    August 14, 2020     August           8.0  14.0  2020.0  14-08-2020
# 1  December 23, 2016   December          12.0  23.0  2016.0  23-12-2016
# 2  December 20, 2018   December          12.0  20.0  2018.0  20-12-2018
# 3  November 16, 2017   November          11.0  16.0  2017.0  16-11-2017
# 4    January 1, 2020    January           1.0   1.0  2020.0  01-01-2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
# 2      R     78 min                Horror Movies, International Movies
# 3  PG-13     80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 4  PG-13    123 min                                             Dramas
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %% [markdown]
# # tail()

# %%
dataframe.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# 7785                                              India       March 2, 2019
# 7786                                                NaN  September 25, 2020
# 7787                                          Australia    October 31, 2020
# 7788              United Kingdom, Canada, United States       March 1, 2020
#
#      month name  month_number  date    year      date.1 Rating  Duration  \
# 7784    October          10.0  19.0  2020.0  19-10-2020  TV-MA    99 min
# 7785      March           3.0   2.0  2019.0  02-03-2019  TV-14   111 min
# 7786  September           9.0  25.0  2020.0  25-09-2020  TV-MA    44 min
# 7787    October          10.0  31.0  2020.0  31-10-2020  TV-PG  1 Season
# 7788      March           3.0   1.0  2020.0  01-03-2020  TV-MA    90 min
#
#                                                    Type  \
# 7784                       Dramas, International Movies
# 7785     Dramas, International Movies, Music & Musicals
# 7786  Documentaries, International Movies, Music & M...
# 7787                 International TV Shows, Reality TV
# 7788                    Documentaries, Music & Musicals
#
#                                             Description
# 7784  When Lebanon's Civil War deprives Zozo of his ...
# 7785  A scrappy but poor boy worms his way into a ty...
# 7786  In this documentary, South African rapper Nast...
# 7787  Dessert wizard Adriano Zumbo looks for the nex...
# 7788  This documentary delves into the mystique behi...

# %% [markdown]
# # shape()

# %%
dataframe.shape
# to show the total number of rows and columns
# Out:
# (7789, 16)

# %% [markdown]
# # size

# %%
dataframe.size
# get elements
# Out:
# 124624

# %% [markdown]
# # columns

# %%
dataframe.columns
# get all column names
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'month name', 'month_number', 'date', 'year', 'date.1',
#        'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# # dtypes

# %%
dataframe.dtypes
# get datatypes of each column
# Out:
# Show_Id          object
# Category         object
# Title            object
# Director         object
# Cast             object
# Country          object
# Release_Date     object
# month name       object
# month_number    float64
# date            float64
# year            float64
# date.1           object
# Rating           object
# Duration         object
# Type             object
# Description      object
# dtype: object

# %% [markdown]
# # info()

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   month name    7779 non-null   object
#  8   month_number  7779 non-null   float64
#  9   date          7779 non-null   float64
#  10  year          7779 non-null   float64
#  11  date.1        7779 non-null   object
#  12  Rating        7782 non-null   object
#  13  Duration      7789 non-null   object
#  14  Type          7789 non-null   object
#  15  Description   7789 non-null   object
# dtypes: float64(3), object(13)
# memory usage: 973.8+ KB

# %%
dataframe.rename(columns = {'date.1':'dates'}, inplace = True)

# %%
dataframe.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date month name  month_number  date    year       dates  \
# 0    August 14, 2020     August           8.0  14.0  2020.0  14-08-2020
# 1  December 23, 2016   December          12.0  23.0  2016.0  23-12-2016
# 2  December 20, 2018   December          12.0  20.0  2018.0  20-12-2018
# 3  November 16, 2017   November          11.0  16.0  2017.0  16-11-2017
# 4    January 1, 2020    January           1.0   1.0  2020.0  01-01-2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
# 2      R     78 min                Horror Movies, International Movies
# 3  PG-13     80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 4  PG-13    123 min                                             Dramas
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %% [markdown]
# Q.1: Is there any duplicate records in the dataset? if yes , then remove the duplicate records.

# %% [markdown]
# # duplicate()

# %%
dataframe[dataframe.duplicated()]
# check duplicated records
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date month name  month_number  date    year       dates  \
# 6300      April 5, 2019      April           4.0   5.0  2019.0  05-04-2019
# 6622  September 4, 2020  September           9.0   4.0  2020.0  04-09-2020
#
#      Rating Duration                                   Type  \
# 6300  TV-MA   97 min  Dramas, Independent Movies, Thrillers
# 6622  TV-MA   94 min   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
#there are 2 duplicate records in the datasets

# %%
dataframe.drop_duplicates(inplace = True)
# remove duplicates records from the dataset

# %%
dataframe[dataframe.duplicated()]
# duplicate records removed
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, month name, month_number, date, year, dates, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# Q.2: Is there any null values in the dataset? check them and show them with hitmap

# %% [markdown]
# # isnull()

# %%
dataframe.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# month name        10
# month_number      10
# date              10
# year              10
# dates             10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
# there are null values in director, cast, country, release_date, month name, month_number,date, year, dates, rating coumns

# %%
sns.heatmap(dataframe.isnull())
plt.title('null values in columns')
# Out:
# Text(0.5, 1.0, 'null values in columns')

# %% [markdown]
# Q.3:for "house of cards", what is the show id and who is the director of the show

# %% [markdown]
# ### isin()

# %%
dataframe.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date month name  month_number  date    year       dates  \
# 0    August 14, 2020     August           8.0  14.0  2020.0  14-08-2020
# 1  December 23, 2016   December          12.0  23.0  2016.0  23-12-2016
# 2  December 20, 2018   December          12.0  20.0  2018.0  20-12-2018
# 3  November 16, 2017   November          11.0  16.0  2017.0  16-11-2017
# 4    January 1, 2020    January           1.0   1.0  2020.0  01-01-2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
# 2      R     78 min                Horror Movies, International Movies
# 3  PG-13     80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 4  PG-13    123 min                                             Dramas
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %%
dataframe['Title'] # to show all records od perticular item in any column
# Out:
# 0                                            3%
# 1                                         07:19
# 2                                         23:59
# 3                                             9
# 4                                            21
#                          ...
# 7784                                       Zozo
# 7785                                     Zubaan
# 7786                          Zulu Man in Japan
# 7787                      Zumbo's Just Desserts
# 7788    ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# Name: Title, Length: 7787, dtype: object

# %%
dataframe[dataframe['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date month name  month_number  date    year       dates  \
# 2832  November 2, 2018   November          11.0   2.0  2018.0  02-11-2018
#
#      Rating   Duration                     Type  \
# 2832  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### str.contains()

# %%
dataframe[dataframe['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date month name  month_number  date    year       dates  \
# 2832  November 2, 2018   November          11.0   2.0  2018.0  02-11-2018
#
#      Rating   Duration                     Type  \
# 2832  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# Q.4:In which year highest number of tv shows and movies were released ? show with bar graph

# %% [markdown]
# ### dtypes

# %%
dataframe.dtypes
# Out:
# Show_Id          object
# Category         object
# Title            object
# Director         object
# Cast             object
# Country          object
# Release_Date     object
# month name       object
# month_number    float64
# date            float64
# year            float64
# dates            object
# Rating           object
# Duration         object
# Type             object
# Description      object
# dtype: object

# %% [markdown]
# ### to_datetime

# %%
dataframe.dtypes
# Out:
# Show_Id          object
# Category         object
# Title            object
# Director         object
# Cast             object
# Country          object
# Release_Date     object
# month name       object
# month_number    float64
# date            float64
# year            float64
# dates            object
# Rating           object
# Duration         object
# Type             object
# Description      object
# dtype: object

# %%
dataframe['year'] = pd.to_datetime(dataframe['dates'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1884\1426179432.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   dataframe['year'] = pd.to_datetime(dataframe['dates'])

# %%
dataframe.dtypes
dataframe.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'month name', 'month_number', 'date', 'year', 'dates',
#        'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
## dt.year.value_counts()

# %%
dataframe['year'].dt.year.value_counts()
# it counts the occurrence of all individual years in date column
# Out:
# year
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %% [markdown]
# # bar graph

# %%
# number of shows and tv released by each year
dataframe['year'].dt.year.value_counts().plot(kind='bar')
plt.title('year wise shows')
# Out:
# Text(0.5, 1.0, 'year wise shows')

# %% [markdown]
# Q.5: How many movies and tv shows are in the dataset ? show with the bar graph

# %% [markdown]
# ### groupby()

# %%
dataframe.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date month name  month_number  date    year       dates  \
# 0    August 14, 2020     August           8.0  14.0  2020.0  14-08-2020
# 1  December 23, 2016   December          12.0  23.0  2016.0  23-12-2016
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
dataframe.groupby('Category').Category.count().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Category'>

# %%
# there are 5377 movies and 2410 tv shows

# %%
dataframe.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'month name', 'month_number', 'date', 'year', 'dates',
#        'Rating', 'Duration', 'Type', 'Description', 'types'],
#       dtype='object')

# %% [markdown]
# Q.6: show all the movies that were released in year 2020

# %%
### creating new column
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7787 entries, 0 to 7788
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   object
#  7   month name    7777 non-null   object
#  8   month_number  7777 non-null   float64
#  9   date          7777 non-null   float64
#  10  year          7777 non-null   datetime64[ns]
#  11  dates         7777 non-null   object
#  12  Rating        7780 non-null   object
#  13  Duration      7787 non-null   object
#  14  Type          7787 non-null   object
#  15  Description   7787 non-null   object
#  16  types         0 non-null      float64
#  17  counts        0 non-null      float64
#  18  years         7777 non-null   float64
# dtypes: datetime64[ns](1), float64(5), object(13)
# memory usage: 1.4+ MB

# %%
dataframe['years'] = dataframe['year'].dt.year

# %%
dataframe.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date month name  month_number  date       year       dates  \
# 0    August 14, 2020     August           8.0  14.0 2020-08-14  14-08-2020
# 1  December 23, 2016   December          12.0  23.0 2016-12-23  23-12-2016
# 2  December 20, 2018   December          12.0  20.0 2018-12-20  20-12-2018
# 3  November 16, 2017   November          11.0  16.0 2017-11-16  16-11-2017
# 4    January 1, 2020    January           1.0   1.0 2020-01-01  01-01-2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
# 2      R     78 min                Horror Movies, International Movies
# 3  PG-13     80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 4  PG-13    123 min                                             Dramas
#
#                                          Description  types  counts   years
# 0  In a future where the elite inhabit an island ...    NaN     NaN  2020.0
# 1  After a devastating earthquake hits Mexico Cit...    NaN     NaN  2016.0
# 2  When an army recruit is found dead, his fellow...    NaN     NaN  2018.0
# 3  In a postapocalyptic world, rag-doll robots hi...    NaN     NaN  2017.0
# 4  A brilliant group of students become card-coun...    NaN     NaN  2020.0

# %%
dataframe[(dataframe['Category'] == 'Movie') & (dataframe['years'] == 2020)]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# 28    Sabina Fedeli, Anna Migotto
# ...                           ...
# 7762                   Wael Ihsan
# 7783                 Peter Hewitt
# 7784                  Josef Fares
# 7786                          NaN
# 7788                     Sam Dunn
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 6     Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...
# 14    Omar Epps, Kate Walsh, Miranda Cosgrove, Angus...
# 27                             Yoo Ah-in, Park Shin-hye
# 28                          Helen Mirren, Gengher Gatti
# ...                                                 ...
# 7762  Ahmed Helmy, Yasmin Abdulaziz, Hassan Hosny, H...
# 7783  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7786                                            Nasty C
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 4                                         United States     January 1, 2020
# 6                                                 Egypt        June 1, 2020
# 14                                        United States      March 19, 2020
# 27                                          South Korea   September 8, 2020
# 28                                                Italy        July 1, 2020
# ...                                                 ...                 ...
# 7762                                              Egypt        May 19, 2020
# 7783                                      United States    January 11, 2020
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# 7786                                                NaN  September 25, 2020
# 7788              United Kingdom, Canada, United States       March 1, 2020
#
#      month name  month_number  date       year       dates Rating Duration  \
# 4       January           1.0   1.0 2020-01-01  01-01-2020  PG-13  123 min
# 6          June           6.0   1.0 2020-06-01  01-06-2020  TV-MA   95 min
# 14        March           3.0  19.0 2020-03-19  19-03-2020      R   91 min
# 27    September           9.0   8.0 2020-09-08  08-09-2020  TV-MA   99 min
# 28         July           7.0   1.0 2020-07-01  01-07-2020  TV-14   95 min
# ...         ...           ...   ...        ...         ...    ...      ...
# 7762        May           5.0  19.0 2020-05-19  19-05-2020  TV-PG  109 min
# 7783    January           1.0  11.0 2020-01-11  11-01-2020     PG   88 min
# 7784    October          10.0  19.0 2020-10-19  19-10-2020  TV-MA   99 min
# 7786  September           9.0  25.0 2020-09-25  25-09-2020  TV-MA   44 min
# 7788      March           3.0   1.0 2020-03-01  01-03-2020  TV-MA   90 min
#
#                                                    Type  \
# 4                                                Dramas
# 6                   Horror Movies, International Movies
# 14      Independent Movies, Sci-Fi & Fantasy, Thrillers
# 27       Horror Movies, International Movies, Thrillers
# 28                  Documentaries, International Movies
# ...                                                 ...
# 7762    Comedies, International Movies, Romantic Movies
# 7783                 Children & Family Movies, Comedies
# 7784                       Dramas, International Movies
# 7786  Documentaries, International Movies, Music & M...
# 7788                    Documentaries, Music & Musicals
#
#                                             Description  types  counts   years
# 4     A brilliant group of students become card-coun...    NaN     NaN  2020.0
# 6     After an awful accident, a couple admitted to ...    NaN     NaN  2020.0
# 14    Stranded when the Earth is suddenly destroyed ...    NaN     NaN  2020.0
# 27    As a grisly virus rampages a city, a lone man ...    NaN     NaN  2020.0
# 28    Through her diary, Anne Frank's story is retol...    NaN     NaN  2020.0
# ...                                                 ...    ...     ...     ...
# 7762  An unqualified young man has his work cut out ...    NaN     NaN  2020.0
# 7783  Dragged from civilian life, a former superhero...    NaN     NaN  2020.0
# 7784  When Lebanon's Civil War deprives Zozo of his ...    NaN     NaN  2020.0
# 7786  In this documentary, South African rapper Nast...    NaN     NaN  2020.0
# 7788  This documentary delves into the mystique behi...    NaN     NaN  2020.0
#
# [1312 rows x 19 columns]

# %% [markdown]
# Q.7: show only the tv shows that were released in india only

# %%
dataframe[(dataframe['Category']== 'TV Show') & (dataframe['Country']== 'India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# Q.8: show top 10 directors who gave the highest number of tv shows & movies to netflix

# %% [markdown]
# ### value_counts()

# %%
dataframe['Director'].value_counts()

# %%
dataframe['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: count, dtype: int64

# %% [markdown]
# Q.9: show all records where category is movie and type is comedy or country is uk

# %%
dataframe[(dataframe['Category']=='Movie') &(dataframe['Type']=='Comedies')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# 33    Nesta Cooper, Kate Walsh, John Michael Higgins...
# 72    Zac Efron, Leslie Mann, Matthew Perry, Thomas ...
# 84    Miles Teller, Skylar Astin, Justin Chon, Sarah...
# 148   Mila Kunis, Kristen Bell, Kathryn Hahn, Susan ...
# 174   Will Forte, Domhnall Gleeson, Martin Mull, Joe...
# ...                                                 ...
# 7341  Michael Jai White, Vince Swann, Barry Bostwick...
# 7590  Andrew Bachelor, Kat Graham, Mike Epps, Terry ...
# 7623  Shirley MacLaine, Jessica Lange, Billy Connoll...
# 7634  Amy Poehler, Maya Rudolph, Ana Gasteyer, Rache...
# 7664  Sabrina Carpenter, Jordan Fisher, Liza Koshy, ...
#
#                      Country       Release_Date month name  month_number  \
# 33             United States  September 8, 2017  September           9.0
# 72             United States    January 1, 2021    January           1.0
# 84             United States     April 16, 2019      April           4.0
# 148     United States, China  February 14, 2020   February           2.0
# 174            United States   January 26, 2018    January           1.0
# ...                      ...                ...        ...           ...
# 7341           United States   November 5, 2019   November          11.0
# 7590           United States   January 22, 2018    January           1.0
# 7623  Germany, United States       May 13, 2017        May           5.0
# 7634           United States       May 10, 2019        May           5.0
# 7664           United States     August 7, 2020     August           8.0
#
#       date       year       dates Rating Duration      Type  \
# 33     8.0 2017-09-08  08-09-2017  TV-14   99 min  Comedies
# 72     1.0 2021-01-01  01-01-2021  PG-13  102 min  Comedies
# 84    16.0 2019-04-16  16-04-2019      R   93 min  Comedies
# 148   14.0 2020-02-14  14-02-2020      R  104 min  Comedies
# 174   26.0 2018-01-26  26-01-2018  TV-MA  102 min  Comedies
# ...    ...        ...         ...    ...      ...       ...
# 7341   5.0 2019-11-05  05-11-2019      R   85 min  Comedies
# 7590  22.0 2018-01-22  22-01-2018      R   86 min  Comedies
# 7623  13.0 2017-05-13  13-05-2017  PG-13   86 min  Comedies
# 7634  10.0 2019-05-10  10-05-2019      R  104 min  Comedies
# 7664   7.0 2020-08-07  07-08-2020  TV-14   94 min  Comedies
#
#                                             Description  types  counts   years
# 33    When nerdy high schooler Dani finally attracts...    NaN     NaN  2017.0
# 72    Nearing a midlife crisis, thirty-something Mik...    NaN     NaN  2021.0
# 84    Jeff's straight-and-narrow life changes abrupt...    NaN     NaN  2019.0
# 148   Stressed-out moms Amy, Carla and Kiki are back...    NaN     NaN  2020.0
# 174   In a brief life full of triumph and failure, "...    NaN     NaN  2018.0
# ...                                                 ...    ...     ...     ...
# 7341  When a beloved secret agent falls deep into a ...    NaN     NaN  2019.0
# 7590  Hunting for a stash of stolen money, a sharp-w...    NaN     NaN  2018.0
# 7623  When insurance accidentally pays her millions,...    NaN     NaN  2017.0
# 7634  When longtime friends meet up for a wine-soake...    NaN     NaN  2019.0
# 7664  A brilliant but clumsy high school senior vows...    NaN     NaN  2020.0
#
# [97 rows x 19 columns]

# %%
dataframe[(dataframe['Category']=='Movie') &(dataframe['Type']=='Comedies') |(dataframe['Country'] == 'United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# 33    Nesta Cooper, Kate Walsh, John Michael Higgins...   United States
# 58    Daniel Palmer, Melissa Sophia, Karen Williams,...  United Kingdom
# 72    Zac Efron, Leslie Mann, Matthew Perry, Thomas ...   United States
# 82    Katee Sackhoff, Ray Fearon, Julie Cox, Steven ...  United Kingdom
# ...                                                 ...             ...
# 7670                                      Robert Powell  United Kingdom
# 7671                 Anita Rani, Ade Adepitan, Dan Snow  United Kingdom
# 7688                                                NaN  United Kingdom
# 7725  Lily O'Regan, Jeannettsy Enriquez Borges, Joel...  United Kingdom
# 7740  Adam Pålsson, Richard Dillane, Leanne Best, El...  United Kingdom
#
#            Release_Date month name  month_number  date       year       dates  \
# 19         May 16, 2018        May           5.0  16.0 2018-05-16  16-05-2018
# 33    September 8, 2017  September           9.0   8.0 2017-09-08  08-09-2017
# 58     November 1, 2019   November          11.0   1.0 2019-11-01  01-11-2019
# 72      January 1, 2021    January           1.0   1.0 2021-01-01  01-01-2021
# 82    December 20, 2018   December          12.0  20.0 2018-12-20  20-12-2018
# ...                 ...        ...           ...   ...        ...         ...
# 7670     August 1, 2017     August           8.0   1.0 2017-08-01  01-08-2017
# 7671   February 1, 2019   February           2.0   1.0 2019-02-01  01-02-2019
# 7688     March 18, 2020      March           3.0  18.0 2020-03-18  18-03-2020
# 7725  December 31, 2017   December          12.0  31.0 2017-12-31  31-12-2017
# 7740  September 3, 2020  September           9.0   3.0 2020-09-03  03-09-2020
#
#      Rating  Duration                                               Type  \
# 19    TV-PG    87 min                                      Sports Movies
# 33    TV-14    99 min                                           Comedies
# 58    TV-14  1 Season  British TV Shows, International TV Shows, Real...
# 72    PG-13   102 min                                           Comedies
# 82    TV-14    95 min                                   Sci-Fi & Fantasy
# ...     ...       ...                                                ...
# 7670  TV-MA  1 Season  British TV Shows, Docuseries, International TV...
# 7671  TV-PG  1 Season                       British TV Shows, Docuseries
# 7688  TV-14    91 min                       Documentaries, Sports Movies
# 7725   TV-G    87 min                           Children & Family Movies
# 7740  TV-MA  1 Season  Crime TV Shows, International TV Shows, TV Dramas
#
#                                             Description  types  counts   years
# 19    Mixing old footage with interviews, this is th...    NaN     NaN  2018.0
# 33    When nerdy high schooler Dani finally attracts...    NaN     NaN  2017.0
# 58    A stylist, a hair designer and a makeup artist...    NaN     NaN  2019.0
# 72    Nearing a midlife crisis, thirty-something Mik...    NaN     NaN  2021.0
# 82    Working with an artificial intelligence to inv...    NaN     NaN  2018.0
# ...                                                 ...    ...     ...     ...
# 7670  Footage of the most dramatic moments from Worl...    NaN     NaN  2017.0
# 7671  From Moscow to Mexico City, three BBC journali...    NaN     NaN  2019.0
# 7688  Set against the 2015 Rugby World Cup, this doc...    NaN     NaN  2020.0
# 7725  A gifted young ballet dancer struggles to find...    NaN     NaN  2017.0
# 7740  An incendiary hate crime stirs civil unrest, f...    NaN     NaN  2020.0
#
# [485 rows x 19 columns]

# %% [markdown]
# Q.10:In how many movies/shows where tom cruise was cast?

# %%
dataframe['Cast'] == 'Tom Cruise'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Name: Cast, Length: 7787, dtype: bool

# %%
data_new = dataframe['Cast'].dropna()

# %%
data_new
# Out:
# 0       João Miguel, Bianca Comparato, Michel Gomes, R...
# 1       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3       Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
#                               ...
# 7783    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 7784    Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                              Nasty C
# 7787                           Adriano Zumbo, Rachel Khoo
# Name: Cast, Length: 7069, dtype: object

# %%
data_new[data_new.str.contains('Tom Cruise')].count()
# there are two movies were tom cruise was casted
# Out:
# 2

# %% [markdown]
# Q.11: what are the different rating defined by netflix

# %%
dataframe['Rating'].nunique()
# Out:
# 14

# %%
dataframe['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# Q12.1:how many movies got tv-14 rating in canada?

# %%
dataframe[(dataframe['Category']=='Movie') & (dataframe['Rating']=='TV-14')]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 15       s16    Movie                    Oct-01      Kunle Afolayan
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7765   s7764    Movie                     Zenda      Avadhoot Gupte
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7770   s7769    Movie  Zindagi Kitni Haseen Hay       Anjum Shahzad
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast   Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...     India
# 15    Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...   Nigeria
# 18    Rahul Pethe, Mrunmayee Deshpande, Adinath Koth...     India
# 20    Geetanjali Thapa, Zain Khan Durrani, Shray Rai...     India
# 21    Samuthirakani, Bharath Seeni, Vinoth, Esakki B...     India
# ...                                                 ...       ...
# 7765  Santosh Juvekar, Siddharth Chandekar, Sachit P...     India
# 7766  Shah Rukh Khan, Anushka Sharma, Katrina Kaif, ...     India
# 7770  Feroze Khan, Sajal Ali, Jibrayl Ahmed Rajput, ...  Pakistan
# 7771  Hrithik Roshan, Abhay Deol, Farhan Akhtar, Kat...     India
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...     India
#
#             Release_Date month name  month_number  date       year  \
# 8          April 1, 2019      April           4.0   1.0 2019-04-01
# 15     September 1, 2019  September           9.0   1.0 2019-09-01
# 18        March 29, 2019      March           3.0  29.0 2019-03-29
# 20     September 1, 2018  September           9.0   1.0 2018-09-01
# 21    September 15, 2018  September           9.0  15.0 2018-09-15
# ...                  ...        ...           ...   ...        ...
# 7765   February 15, 2018   February           2.0  15.0 2018-02-15
# 7766        May 21, 2019        May           5.0  21.0 2019-05-21
# 7770     October 1, 2018    October          10.0   1.0 2018-10-01
# 7771   December 15, 2019   December          12.0  15.0 2019-12-15
# 7785       March 2, 2019      March           3.0   2.0 2019-03-02
#
#            dates Rating Duration  \
# 8     01-04-2019  TV-14  118 min
# 15    01-09-2019  TV-14  149 min
# 18    29-03-2019  TV-14  124 min
# 20    01-09-2018  TV-14  110 min
# 21    15-09-2018  TV-14  128 min
# ...          ...    ...      ...
# 7765  15-02-2018  TV-14  120 min
# 7766  21-05-2019  TV-14  159 min
# 7770  01-10-2018  TV-14  126 min
# 7771  15-12-2019  TV-14  154 min
# 7785  02-03-2019  TV-14  111 min
#
#                                                   Type  \
# 8                  Horror Movies, International Movies
# 15             Dramas, International Movies, Thrillers
# 18                Comedies, Dramas, Independent Movies
# 20    Dramas, Independent Movies, International Movies
# 21    Action & Adventure, Dramas, International Movies
# ...                                                ...
# 7765                      Dramas, International Movies
# 7766            Comedies, Dramas, International Movies
# 7770     Dramas, International Movies, Romantic Movies
# 7771            Comedies, Dramas, International Movies
# 7785    Dramas, International Movies, Music & Musicals
#
#                                             Description  types  counts   years
# 8     When a doctor goes missing, his psychiatrist w...    NaN     NaN  2019.0
# 15    Against the backdrop of Nigeria's looming inde...    NaN     NaN  2019.0
# 18    On India's Independence Day, a zany mishap in ...    NaN     NaN  2019.0
# 20    After accidentally connecting over the Interne...    NaN     NaN  2018.0
# 21    A taxi driver, a gangster and an athlete strug...    NaN     NaN  2018.0
# ...                                                 ...    ...     ...     ...
# 7765  A change in the leadership of a political part...    NaN     NaN  2018.0
# 7766  Through his relationships with two wildly diff...    NaN     NaN  2019.0
# 7770  Two young parents struggle to keep their marri...    NaN     NaN  2018.0
# 7771  Three friends on an adventurous road trip/bach...    NaN     NaN  2019.0
# 7785  A scrappy but poor boy worms his way into a ty...    NaN     NaN  2019.0
#
# [1272 rows x 19 columns]

# %%
dataframe[(dataframe['Category']=='Movie') & (dataframe['Rating']=='TV-14') & (dataframe['Country']=='Canada')].shape
# Out:
# (11, 19)

# %% [markdown]
# Q12.2: how many tv  shows got r rating after year 2018

# %%
dataframe[(dataframe['Category']=='TV Show') & (dataframe['Rating']=='R')]

# %%
dataframe[(dataframe['Category']=='TV Show') & (dataframe['Rating']=='R') & (dataframe['year']> 2018)]

# %% [markdown]
# Q.13: what is the maximum duration of a movie on netflix?

# %%
dataframe['Duration'].unique()

# %%
dataframe.Duration.dtypes

# %%
dataframe[['Minutes','Unit']] = dataframe['Duration'].str.split(' ',expand= True)
# str.split fucntions to specific values from the column
# here splitng duration column into minute and unit(min for minutes,Seasons for seasons)

# %%
dataframe.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date month name  month_number  date  ...       dates Rating  \
# 0    August 14, 2020     August           8.0  14.0  ...  14-08-2020  TV-MA
# 1  December 23, 2016   December          12.0  23.0  ...  23-12-2016  TV-MA
# 2  December 20, 2018   December          12.0  20.0  ...  20-12-2018      R
# 3  November 16, 2017   November          11.0  16.0  ...  16-11-2017  PG-13
# 4    January 1, 2020    January           1.0   1.0  ...  01-01-2020  PG-13
#
#     Duration                                               Type  \
# 0  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     93 min                       Dramas, International Movies
# 2     78 min                Horror Movies, International Movies
# 3     80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 4    123 min                                             Dramas
#
#                                          Description types  counts   years  \
# 0  In a future where the elite inhabit an island ...   NaN     NaN  2020.0
# 1  After a devastating earthquake hits Mexico Cit...   NaN     NaN  2016.0
# 2  When an army recruit is found dead, his fellow...   NaN     NaN  2018.0
# 3  In a postapocalyptic world, rag-doll robots hi...   NaN     NaN  2017.0
# 4  A brilliant group of students become card-coun...   NaN     NaN  2020.0
#
#    Minutes     Unit
# 0        4  Seasons
# 1       93      min
# 2       78      min
# 3       80      min
# 4      123      min
#
# [5 rows x 21 columns]

# %%
dataframe[dataframe['Minutes'] == dataframe['Minutes'].max()]
# there are 101 movies in dataset which are having maximum duration of 99 minutes
# Out:
#      Show_Id Category                                        Title  \
# 27       s28    Movie                                       #Alive
# 33       s34    Movie                                 #realityhigh
# 42       s43    Movie                  Çok Filim Hareketler Bunlar
# 121     s122    Movie                               50 First Dates
# 147     s148    Movie      A Babysitter's Guide to Monster Hunting
# ...      ...      ...                                          ...
# 7449   s7448    Movie                                          VS.
# 7527   s7526    Movie                        Welcome Mr. President
# 7559   s7558    Movie                         What Keeps You Alive
# 7638   s7637    Movie  Winter on Fire: Ukraine's Fight for Freedom
# 7784   s7783    Movie                                         Zozo
#
#                Director                                               Cast  \
# 27               Cho Il                           Yoo Ah-in, Park Shin-hye
# 33     Fernando Lebrija  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 42         Ozan Açıktan  Ayça Erturan, Aydan Taş, Ayşegül Akdemir, Burc...
# 121         Peter Segal  Adam Sandler, Drew Barrymore, Rob Schneider, S...
# 147      Rachel Talalay  Tamara Smart, Oona Laurence, Tom Felton, Troy ...
# ...                 ...                                                ...
# 7449           Ed Lilly  Connor Swindells, Fola Evans-Akingbola, Nichol...
# 7527    Riccardo Milani  Claudio Bisio, Kasia Smutniak, Beppe Fiorello,...
# 7559      Colin Minihan  Hannah Emily Anderson, Brittany Allen, Martha ...
# 7638  Evgeny Afineevsky                                                NaN
# 7784        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
#
#                                                 Country       Release_Date  \
# 27                                          South Korea  September 8, 2020
# 33                                        United States  September 8, 2017
# 42                                               Turkey     March 10, 2017
# 121                                       United States   December 1, 2020
# 147                                       United States   October 15, 2020
# ...                                                 ...                ...
# 7449                                     United Kingdom      June 19, 2019
# 7527                                              Italy    October 1, 2016
# 7559                                             Canada     August 1, 2020
# 7638             United Kingdom, Ukraine, United States    October 9, 2015
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...   October 19, 2020
#
#      month name  month_number  date  ...       dates Rating Duration  \
# 27    September           9.0   8.0  ...  08-09-2020  TV-MA   99 min
# 33    September           9.0   8.0  ...  08-09-2017  TV-14   99 min
# 42        March           3.0  10.0  ...  10-03-2017  TV-MA   99 min
# 121    December          12.0   1.0  ...  01-12-2020  PG-13   99 min
# 147     October          10.0  15.0  ...  15-10-2020  TV-PG   99 min
# ...         ...           ...   ...  ...         ...    ...      ...
# 7449       June           6.0  19.0  ...  19-06-2019  TV-MA   99 min
# 7527    October          10.0   1.0  ...  01-10-2016  TV-MA   99 min
# 7559     August           8.0   1.0  ...  01-08-2020      R   99 min
# 7638    October          10.0   9.0  ...  09-10-2015  TV-MA   99 min
# 7784    October          10.0  19.0  ...  19-10-2020  TV-MA   99 min
#
#                                                 Type  \
# 27    Horror Movies, International Movies, Thrillers
# 33                                          Comedies
# 42                    Comedies, International Movies
# 121                        Comedies, Romantic Movies
# 147                         Children & Family Movies
# ...                                              ...
# 7449                                          Dramas
# 7527                  Comedies, International Movies
# 7559                         LGBTQ Movies, Thrillers
# 7638             Documentaries, International Movies
# 7784                    Dramas, International Movies
#
#                                             Description types  counts   years  \
# 27    As a grisly virus rampages a city, a lone man ...   NaN     NaN  2020.0
# 33    When nerdy high schooler Dani finally attracts...   NaN     NaN  2017.0
# 42    Vignettes of the summer holidays follow vacati...   NaN     NaN  2017.0
# 121   After falling for a pretty art teacher who has...   NaN     NaN  2020.0
# 147   Recruited by a secret society of babysitters, ...   NaN     NaN  2020.0
# ...                                                 ...   ...     ...     ...
# 7449  A young man in foster care finds his voice in ...   NaN     NaN  2019.0
# 7527  When frustrated politicians name a historical ...   NaN     NaN  2016.0
# 7559  A couple's romantic anniversary retreat to a r...   NaN     NaN  2020.0
# 7638  Over 93 days in Ukraine, what started as peace...   NaN     NaN  2015.0
# 7784  When Lebanon's Civil War deprives Zozo of his ...   NaN     NaN  2020.0
#
#       Minutes Unit
# 27         99  min
# 33         99  min
# 42         99  min
# 121        99  min
# 147        99  min
# ...       ...  ...
# 7449       99  min
# 7527       99  min
# 7559       99  min
# 7638       99  min
# 7784       99  min
#
# [101 rows x 21 columns]

# %% [markdown]
# Q.14:which individual country has most number of tv shows

# %%
#creating new data frame
data_tvshow = dataframe[dataframe['Category'] == 'TV Show']

# %%
data_tvshow.head()
# Out:
#    Show_Id Category   Title              Director  \
# 0       s1  TV Show      3%                   NaN
# 5       s6  TV Show      46           Serdar Akar
# 11     s12  TV Show    1983                   NaN
# 12     s13  TV Show    1994  Diego Enrique Osorno
# 16     s17  TV Show  Feb-09                   NaN
#
#                                                  Cast                Country  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...                 Brazil
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...                 Turkey
# 11  Robert Więckiewicz, Maciej Musiał, Michalina O...  Poland, United States
# 12                                                NaN                 Mexico
# 16  Shahd El Yaseen, Shaila Sabt, Hala, Hanadi Al-...                    NaN
#
#          Release_Date month name  month_number  date  ...       dates Rating  \
# 0     August 14, 2020     August           8.0  14.0  ...  14-08-2020  TV-MA
# 5        July 1, 2017       July           7.0   1.0  ...  01-07-2017  TV-MA
# 11  November 30, 2018   November          11.0  30.0  ...  30-11-2018  TV-MA
# 12       May 17, 2019        May           5.0  17.0  ...  17-05-2019  TV-MA
# 16     March 20, 2019      March           3.0  20.0  ...  20-03-2019  TV-14
#
#      Duration                                               Type  \
# 0   4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5    1 Season    International TV Shows, TV Dramas, TV Mysteries
# 11   1 Season  Crime TV Shows, International TV Shows, TV Dramas
# 12   1 Season  Crime TV Shows, Docuseries, International TV S...
# 16   1 Season                  International TV Shows, TV Dramas
#
#                                           Description types  counts   years  \
# 0   In a future where the elite inhabit an island ...   NaN     NaN  2020.0
# 5   A genetics professor experiments with a treatm...   NaN     NaN  2017.0
# 11  In this dark alt-history thriller, a naïve law...   NaN     NaN  2018.0
# 12  Archival video and new interviews examine Mexi...   NaN     NaN  2019.0
# 16  As a psychology professor faces Alzheimer's, h...   NaN     NaN  2019.0
#
#     Minutes     Unit
# 0         4  Seasons
# 5         1   Season
# 11        1   Season
# 12        1   Season
# 16        1   Season
#
# [5 rows x 21 columns]

# %%
data_tvshow.Country.value_counts()
# Out:
# Country
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: count, Length: 183, dtype: int64

# %%
data_tvshow.Country.value_counts().head(1)

# %%
# united states has most tv shows i.e, 705
# united kingdom comes at second position with 204 tv shows
# At third we have Japan with 157 tv shows

# %% [markdown]
# Q.15: how we can sort dataset by year

# %%
dataframe.sort_values(by='year',ascending = False)
# Out:
#      Show_Id Category                         Title  \
# 1673   s1674    Movie                   Death of Me
# 5060   s5060    Movie                  Radium Girls
# 205     s206    Movie               A Monster Calls
# 1832   s1833    Movie                    Double Dad
# 4710   s4711    Movie              Outside the Wire
# ...      ...      ...                           ...
# 3374   s3375  TV Show                      Kikoriki
# 3492   s3493  TV Show           La Familia P. Luche
# 3946   s3947  TV Show                         Maron
# 5138   s5138  TV Show                  Red vs. Blue
# 6066   s6066  TV Show  The Adventures of Figaro Pho
#
#                               Director  \
# 1673               Darren Lynn Bousman
# 5060  Lydia Dean Pilcher, Ginny Mohler
# 205                        J.A. Bayona
# 1832                      Cris D'Amato
# 4710                   Mikael Håfström
# ...                                ...
# 3374                               NaN
# 3492                               NaN
# 3946                               NaN
# 5138                               NaN
# 6066                               NaN
#
#                                                    Cast  \
# 1673  Maggie Q, Luke Hemsworth, Alex Essoe, Ingkarat...
# 5060  Joey King, Abby Quinn, Cara Seymour, Scott She...
# 205   Lewis MacDougall, Sigourney Weaver, Felicity J...
# 1832  Maisa Silva, Eduardo Moscovis, Marcelo Médici,...
# 4710  Anthony Mackie, Damson Idris, Emily Beecham, M...
# ...                                                 ...
# 3374                                      Igor Dmitriev
# 3492  Eugenio Derbez, Consuelo Duval, Luis Manuel Áv...
# 3946  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...
# 5138  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...
# 6066  Luke Jurevicius, Craig Behenna, Charlotte Haml...
#
#                                    Country      Release_Date month name  \
# 1673               United States, Thailand  January 16, 2021    January
# 5060                         United States  January 16, 2021    January
# 205   United Kingdom, Spain, United States  January 16, 2021    January
# 1832                                Brazil  January 15, 2021    January
# 4710                                   NaN  January 15, 2021    January
# ...                                    ...               ...        ...
# 3374                                   NaN               NaN        NaN
# 3492                         United States               NaN        NaN
# 3946                         United States               NaN        NaN
# 5138                         United States               NaN        NaN
# 6066                             Australia               NaN        NaN
#
#       month_number  date  ...       dates Rating    Duration  \
# 1673           1.0  16.0  ...  16-01-2021      R      94 min
# 5060           1.0  16.0  ...  16-01-2021  TV-14     103 min
# 205            1.0  16.0  ...  16-01-2021  PG-13     108 min
# 1832           1.0  15.0  ...  15-01-2021   TV-G     105 min
# 4710           1.0  15.0  ...  15-01-2021      R     116 min
# ...            ...   ...  ...         ...    ...         ...
# 3374           NaN   NaN  ...         NaN   TV-Y   2 Seasons
# 3492           NaN   NaN  ...         NaN  TV-14   3 Seasons
# 3946           NaN   NaN  ...         NaN  TV-MA   4 Seasons
# 5138           NaN   NaN  ...         NaN     NR  13 Seasons
# 6066           NaN   NaN  ...         NaN  TV-Y7   2 Seasons
#
#                                                    Type  \
# 1673                                      Horror Movies
# 5060                         Dramas, Independent Movies
# 205                            Dramas, Sci-Fi & Fantasy
# 1832         Children & Family Movies, Comedies, Dramas
# 4710                                 Action & Adventure
# ...                                                 ...
# 3374                                           Kids' TV
# 3492  International TV Shows, Spanish-Language TV Sh...
# 3946                                        TV Comedies
# 5138  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 6066                              Kids' TV, TV Comedies
#
#                                             Description types  counts   years  \
# 1673  With no memory of the previous night, a vacati...   NaN     NaN  2021.0
# 5060  When the women at a radium factory begin to fa...   NaN     NaN  2021.0
# 205   Overwhelmed by his mother’s illness, a young b...   NaN     NaN  2021.0
# 1832  While her mom is away, a teen sneaks out of th...   NaN     NaN  2021.0
# 4710  In the near future, a drone pilot sent into a ...   NaN     NaN  2021.0
# ...                                                 ...   ...     ...     ...
# 3374  A wacky rabbit and his gang of animal pals hav...   NaN     NaN     NaN
# 3492  This irreverent sitcom featues Ludovico, Feder...   NaN     NaN     NaN
# 3946  Marc Maron stars as Marc Maron, who interviews...   NaN     NaN     NaN
# 5138  This parody of first-person shooter games, mil...   NaN     NaN     NaN
# 6066  Imagine your worst fears, then multiply them: ...   NaN     NaN     NaN
#
#       Minutes     Unit
# 1673       94      min
# 5060      103      min
# 205       108      min
# 1832      105      min
# 4710      116      min
# ...       ...      ...
# 3374        2  Seasons
# 3492        3  Seasons
# 3946        4  Seasons
# 5138       13  Seasons
# 6066        2  Seasons
#
# [7787 rows x 21 columns]

# %% [markdown]
# ### Q16.: find all intances where:

# %% [markdown]
# ### 1 Category is movie and type is dramas

# %% [markdown]
# ### or

# %% [markdown]
# ### 2 category is tv shows and type is kids tv

# %%
dataframe.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date month name  month_number  date  ...       dates Rating  \
# 0    August 14, 2020     August           8.0  14.0  ...  14-08-2020  TV-MA
# 1  December 23, 2016   December          12.0  23.0  ...  23-12-2016  TV-MA
#
#     Duration                                               Type  \
# 0  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     93 min                       Dramas, International Movies
#
#                                          Description types  counts   years  \
# 0  In a future where the elite inhabit an island ...   NaN     NaN  2020.0
# 1  After a devastating earthquake hits Mexico Cit...   NaN     NaN  2016.0
#
#    Minutes     Unit
# 0        4  Seasons
# 1       93      min
#
# [2 rows x 21 columns]

# %%
dataframe[(dataframe['Category'] == 'Movie') &(dataframe['Type']=='Dramas')]
# list of movies where type is drama
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 170   Gerard Butler, Gretchen Mol, Alison Brie, Will...
# 232   Ken Olin, Jill Eikenberry, Maureen Mueller, Gr...
# 295   Ben Hyland, Marsha Mason, Karina Smirnoff, Col...
# ...                                                 ...
# 7417  Patrick Davis, Lisa Vidal, Josh Pence, José Zú...
# 7422  Craig Fairbrass, George Russo, Robert Gleniste...
# 7449  Connor Swindells, Fola Evans-Akingbola, Nichol...
# 7465  Bryan Cranston, Jennifer Garner, Jason O'Mara,...
# 7480  Emily Watson, David Thewlis, Peter Mullan, Nie...
#
#                     Country       Release_Date month name  month_number  date  \
# 4             United States    January 1, 2020    January           1.0   1.0
# 7             United States   November 1, 2019   November          11.0   1.0
# 170   Canada, United States  December 15, 2019   December          12.0  15.0
# 232           United States    October 1, 2011    October          10.0   1.0
# 295           United States   December 1, 2016   December          12.0   1.0
# ...                     ...                ...        ...           ...   ...
# 7417          United States      July 24, 2017       July           7.0  24.0
# 7422         United Kingdom  September 5, 2020  September           9.0   5.0
# 7449         United Kingdom      June 19, 2019       June           6.0  19.0
# 7465          United States      March 2, 2019      March           3.0   2.0
# 7480   United States, India        May 6, 2019        May           5.0   6.0
#
#       ...       dates Rating Duration    Type  \
# 4     ...  01-01-2020  PG-13  123 min  Dramas
# 7     ...  01-11-2019      R  119 min  Dramas
# 170   ...  15-12-2019      R  110 min  Dramas
# 232   ...  01-10-2011  TV-14   95 min  Dramas
# 295   ...  01-12-2016  TV-PG   24 min  Dramas
# ...   ...         ...    ...      ...     ...
# 7417  ...  24-07-2017  PG-13  110 min  Dramas
# 7422  ...  05-09-2020      R   97 min  Dramas
# 7449  ...  19-06-2019  TV-MA   99 min  Dramas
# 7465  ...  02-03-2019      R  109 min  Dramas
# 7480  ...  06-05-2019  PG-13  147 min  Dramas
#
#                                             Description types  counts   years  \
# 4     A brilliant group of students become card-coun...   NaN     NaN  2020.0
# 7     After one of his high school students attacks ...   NaN     NaN  2019.0
# 170   A ruthless corporate headhunter battles his ri...   NaN     NaN  2019.0
# 232   After reckless teens kill an Amish child, a pr...   NaN     NaN  2011.0
# 295   A young boy, upset by his parents' divorce, be...   NaN     NaN  2016.0
# ...                                                 ...   ...     ...     ...
# 7417  In 1962 Brooklyn, a Puerto Rican teen who join...   NaN     NaN  2017.0
# 7422  Fresh out of prison, an ex-con tries to save h...   NaN     NaN  2020.0
# 7449  A young man in foster care finds his voice in ...   NaN     NaN  2019.0
# 7465  An unhappy father and lawyer quits his suburba...   NaN     NaN  2019.0
# 7480  During World War I, the bond between a young E...   NaN     NaN  2019.0
#
#       Minutes Unit
# 4         123  min
# 7         119  min
# 170       110  min
# 232        95  min
# 295        24  min
# ...       ...  ...
# 7417      110  min
# 7422       97  min
# 7449       99  min
# 7465      109  min
# 7480      147  min
#
# [117 rows x 21 columns]

# %%
dataframe[(dataframe['Category'] == 'Movie') &(dataframe['Type']=="Kids' TV")]
# list of movies made for kids
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, month name, month_number, date, year, dates, Rating, Duration, Type, Description, types, counts, years, Minutes, Unit]
# Index: []
#
# [0 rows x 21 columns]

# %%
dataframe[(dataframe['Category'] == 'Movie') &(dataframe['Type']=='Dramas')|
           (dataframe['Category'] == 'TV Shows') &(dataframe['Type']=="Kids' TV") ]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 170   Gerard Butler, Gretchen Mol, Alison Brie, Will...
# 232   Ken Olin, Jill Eikenberry, Maureen Mueller, Gr...
# 295   Ben Hyland, Marsha Mason, Karina Smirnoff, Col...
# ...                                                 ...
# 7417  Patrick Davis, Lisa Vidal, Josh Pence, José Zú...
# 7422  Craig Fairbrass, George Russo, Robert Gleniste...
# 7449  Connor Swindells, Fola Evans-Akingbola, Nichol...
# 7465  Bryan Cranston, Jennifer Garner, Jason O'Mara,...
# 7480  Emily Watson, David Thewlis, Peter Mullan, Nie...
#
#                     Country       Release_Date month name  month_number  date  \
# 4             United States    January 1, 2020    January           1.0   1.0
# 7             United States   November 1, 2019   November          11.0   1.0
# 170   Canada, United States  December 15, 2019   December          12.0  15.0
# 232           United States    October 1, 2011    October          10.0   1.0
# 295           United States   December 1, 2016   December          12.0   1.0
# ...                     ...                ...        ...           ...   ...
# 7417          United States      July 24, 2017       July           7.0  24.0
# 7422         United Kingdom  September 5, 2020  September           9.0   5.0
# 7449         United Kingdom      June 19, 2019       June           6.0  19.0
# 7465          United States      March 2, 2019      March           3.0   2.0
# 7480   United States, India        May 6, 2019        May           5.0   6.0
#
#       ...       dates Rating Duration    Type  \
# 4     ...  01-01-2020  PG-13  123 min  Dramas
# 7     ...  01-11-2019      R  119 min  Dramas
# 170   ...  15-12-2019      R  110 min  Dramas
# 232   ...  01-10-2011  TV-14   95 min  Dramas
# 295   ...  01-12-2016  TV-PG   24 min  Dramas
# ...   ...         ...    ...      ...     ...
# 7417  ...  24-07-2017  PG-13  110 min  Dramas
# 7422  ...  05-09-2020      R   97 min  Dramas
# 7449  ...  19-06-2019  TV-MA   99 min  Dramas
# 7465  ...  02-03-2019      R  109 min  Dramas
# 7480  ...  06-05-2019  PG-13  147 min  Dramas
#
#                                             Description types  counts   years  \
# 4     A brilliant group of students become card-coun...   NaN     NaN  2020.0
# 7     After one of his high school students attacks ...   NaN     NaN  2019.0
# 170   A ruthless corporate headhunter battles his ri...   NaN     NaN  2019.0
# 232   After reckless teens kill an Amish child, a pr...   NaN     NaN  2011.0
# 295   A young boy, upset by his parents' divorce, be...   NaN     NaN  2016.0
# ...                                                 ...   ...     ...     ...
# 7417  In 1962 Brooklyn, a Puerto Rican teen who join...   NaN     NaN  2017.0
# 7422  Fresh out of prison, an ex-con tries to save h...   NaN     NaN  2020.0
# 7449  A young man in foster care finds his voice in ...   NaN     NaN  2019.0
# 7465  An unhappy father and lawyer quits his suburba...   NaN     NaN  2019.0
# 7480  During World War I, the bond between a young E...   NaN     NaN  2019.0
#
#       Minutes Unit
# 4         123  min
# 7         119  min
# 170       110  min
# 232        95  min
# 295        24  min
# ...       ...  ...
# 7417      110  min
# 7422       97  min
# 7449       99  min
# 7465      109  min
# 7480      147  min
#
# [117 rows x 21 columns]
